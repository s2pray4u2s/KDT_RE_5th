# %% [markdown]
# ## 09. Folium
# - 지도 시각화 라이브러리

# %%
# ======================================
# 0. 기본 라이브러리
# ======================================
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium

import matplotlib.font_manager as fm
from matplotlib import rcParams

# ======================================
# 1. 스타일 먼저 (중요: 폰트보다 먼저)
# ======================================
plt.style.use('_mpl-gallery-nogrid')   # matplotlib 스타일
sns.set_theme(style="white")           # seaborn 기본 테마

# ======================================
# 2. 폰트 설정 (나눔고딕)
# ======================================
FONT_PATH = r"C:/Users/user/Desktop/wdh/NanumGothic.ttf"

# matplotlib에 폰트 등록
fm.fontManager.addfont(FONT_PATH)

# 전역 폰트 지정
rcParams["font.family"] = "NanumGothic"

# 마이너스 깨짐 방지
rcParams["axes.unicode_minus"] = False

# (선택) 기본 폰트 사이즈 살짝 키우기
rcParams["font.size"] = 12
rcParams["axes.titlesize"] = 18
rcParams["axes.labelsize"] = 14
rcParams["xtick.labelsize"] = 12
rcParams["ytick.labelsize"] = 12

# ======================================
# 3. 개별 객체용 폰트 (pie, title 등)
# ======================================
font_prop = fm.FontProperties(fname=FONT_PATH)

# ======================================
# 4. seaborn스타일 설정
# ======================================
sns.set_style("ticks") # 스타일 테마 설정
sns.set_context("notebook") # 문맥에 따라 스타일 크기 조정
sns.set_palette("pastel")

# %%
# 기본 지도 생성
my_map = folium.Map(location = [37.5665, 126.9780] , zoom_start = 13)

# 기본 마커
folium.Marker([37.5665, 126.9780], popup = "Cityhall", tooltip = "서울특별시청", icon = folium.Icon(color = "black", icon = "fa-solid fa-bus", prefix = "fa-solid")).add_to(my_map)

# 원형 마커
folium.CircleMarker([37.5727, 126.9743], radius = 100, color = "#adcdff", fill = True, fill_color = "#1c73ff", popup = "CircleMaker", tooltip = "tooltip").add_to(my_map) 

# 클릭한 곳에 마커 추가
my_map.add_child(folium.ClickForMarker(popup = " 내가 클릭한 곳"))

# 클릭한 곳의 위도와 경도를 표시
my_map.add_child(folium.LatLngPopup())
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aaa718098e77adae75cdbe6af329e6fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aaa718098e77adae75cdbe6af329e6fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aaa718098e77adae75cdbe6af329e6fc = L.map(
#                 &quot;map_aaa718098e77adae75cdbe6af329e6fc&quot;,
#                 {
#                     center: [37.5665, 126.978],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_041666eebadf08b05aa1e7157f9e5d71 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_041666eebadf08b05aa1e7157f9e5d71.addTo(map_aaa718098e77adae75cdbe6af329e6fc);
#
#
#             var marker_f81e7a066351791fd9dbf83df5726aab = L.marker(
#                 [37.5665, 126.978],
#                 {
# }
#             ).addTo(map_aaa718098e77adae75cdbe6af329e6fc);
#
#
#             var icon_07e4cc7094cb363cc47b7ba7ecaea433 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-solid fa-bus&quot;,
#   &quot;prefix&quot;: &quot;fa-solid&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fc9ab9bd9f917e47d2c22c3a45901d75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2f25851153080d0e62a11a3e9cf3a51 = $(`&lt;div id=&quot;html_b2f25851153080d0e62a11a3e9cf3a51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cityhall&lt;/div&gt;`)[0];
#                 popup_fc9ab9bd9f917e47d2c22c3a45901d75.setContent(html_b2f25851153080d0e62a11a3e9cf3a51);
#
#
#
#         marker_f81e7a066351791fd9dbf83df5726aab.bindPopup(popup_fc9ab9bd9f917e47d2c22c3a45901d75)
#         ;
#
#
#
#
#             marker_f81e7a066351791fd9dbf83df5726aab.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시청
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_f81e7a066351791fd9dbf83df5726aab.setIcon(icon_07e4cc7094cb363cc47b7ba7ecaea433);
#
#
#             var circle_marker_1d7059714a721cff9e2e8d45dcc0a833 = L.circleMarker(
#                 [37.5727, 126.9743],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#adcdff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1c73ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aaa718098e77adae75cdbe6af329e6fc);
#
#
#         var popup_61e43e302a1fe41410a8b808160320d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc7094e19b040e72583996d83757a052 = $(`&lt;div id=&quot;html_cc7094e19b040e72583996d83757a052&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CircleMaker&lt;/div&gt;`)[0];
#                 popup_61e43e302a1fe41410a8b808160320d9.setContent(html_cc7094e19b040e72583996d83757a052);
#
#
#
#         circle_marker_1d7059714a721cff9e2e8d45dcc0a833.bindPopup(popup_61e43e302a1fe41410a8b808160320d9)
#         ;
#
#
#
#
#             circle_marker_1d7059714a721cff9e2e8d45dcc0a833.bindTooltip(
#                 `&lt;div&gt;
#                      tooltip
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 function newMarker(e){
#                     var new_mark = L.marker().setLatLng(e.latlng).addTo(map_aaa718098e77adae75cdbe6af329e6fc);
#                     new_mark.dragging.enable();
#                     new_mark.on(&#x27;dblclick&#x27;, function(e){ map_aaa718098e77adae75cdbe6af329e6fc.removeLayer(e.target)})
#                     var lat = e.latlng.lat.toFixed(4),
#                        lng = e.latlng.lng.toFixed(4);
#                     new_mark.bindPopup(` 내가 클릭한 곳`);
#                     };
#                 map_aaa718098e77adae75cdbe6af329e6fc.on(&#x27;click&#x27;, newMarker);
#
#
#                 var lat_lng_popup_6881dd26cd3ed1c851ba6546d47d5b37 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_6881dd26cd3ed1c851ba6546d47d5b37
#                         .setLatLng(e.latlng)

# %%
my_map1 = folium.Map(location=[36.5, 127.8], zoom_start=7)

plants = [
    ["영흥화력발전소", 37.2383, 126.4286],
    ["당진화력발전소", 37.0291, 126.5039],
    ["태안화력발전소", 36.7492, 126.1516]
]

for name, lat, lon in plants:
    folium.Marker(
        [lat, lon],
        popup=name,
        icon=folium.Icon(color="blue", icon="bolt")
    ).add_to(my_map1)

my_map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93287f64823fecbf561a2e12a7f6ac62 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93287f64823fecbf561a2e12a7f6ac62&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93287f64823fecbf561a2e12a7f6ac62 = L.map(
#                 &quot;map_93287f64823fecbf561a2e12a7f6ac62&quot;,
#                 {
#                     center: [36.5, 127.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e7af42a316115b1274dbac0f9cfac26 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1e7af42a316115b1274dbac0f9cfac26.addTo(map_93287f64823fecbf561a2e12a7f6ac62);
#
#
#             var marker_dbfd98dfd85d996589f9a505aea9857e = L.marker(
#                 [37.2383, 126.4286],
#                 {
# }
#             ).addTo(map_93287f64823fecbf561a2e12a7f6ac62);
#
#
#             var icon_43914cb5c1edf3c076882da0d00d5941 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;bolt&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8a74d659ee151b27eee7d6f5c77da5b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_196e2e3b5211c46414aa9da66f087878 = $(`&lt;div id=&quot;html_196e2e3b5211c46414aa9da66f087878&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;영흥화력발전소&lt;/div&gt;`)[0];
#                 popup_8a74d659ee151b27eee7d6f5c77da5b6.setContent(html_196e2e3b5211c46414aa9da66f087878);
#
#
#
#         marker_dbfd98dfd85d996589f9a505aea9857e.bindPopup(popup_8a74d659ee151b27eee7d6f5c77da5b6)
#         ;
#
#
#
#
#                 marker_dbfd98dfd85d996589f9a505aea9857e.setIcon(icon_43914cb5c1edf3c076882da0d00d5941);
#
#
#             var marker_379a144cdd7c1bf0bf6620c612193f7b = L.marker(
#                 [37.0291, 126.5039],
#                 {
# }
#             ).addTo(map_93287f64823fecbf561a2e12a7f6ac62);
#
#
#             var icon_bb19e6fd0c0693418508b7ecca1818d7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;bolt&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e9f511dd1de3c14694acaa473c38e24a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5647c27a89dcb51f2f408bf77f02a563 = $(`&lt;div id=&quot;html_5647c27a89dcb51f2f408bf77f02a563&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;당진화력발전소&lt;/div&gt;`)[0];
#                 popup_e9f511dd1de3c14694acaa473c38e24a.setContent(html_5647c27a89dcb51f2f408bf77f02a563);
#
#
#
#         marker_379a144cdd7c1bf0bf6620c612193f7b.bindPopup(popup_e9f511dd1de3c14694acaa473c38e24a)
#         ;
#
#
#
#
#                 marker_379a144cdd7c1bf0bf6620c612193f7b.setIcon(icon_bb19e6fd0c0693418508b7ecca1818d7);
#
#
#             var marker_27abd6035cdbbcb9eb50592ee8ceae84 = L.marker(
#                 [36.7492, 126.1516],
#                 {
# }
#             ).addTo(map_93287f64823fecbf561a2e12a7f6ac62);
#
#
#             var icon_98086c641db4d1a1c6bed49379052c65 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;bolt&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c762572a53db36e7504fe56d5fc5f946 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c98c372f806ec0cd344fc568b281552d = $(`&lt;div id=&quot;html_c98c372f806ec0cd344fc568b281552d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;태안화력발전소&lt;/div&gt;`)[0];
#                 popup_c762572a53db36e7504fe56d5fc5f946.setContent(html_c98c372f806ec0cd344fc568b281552d);
#
#
#
#         marker_27abd6035cdbbcb9eb50592ee8ceae84.bindPopup(popup_c762572a53db36e7504fe56d5fc5f946)
#         ;
#
#
#
#
#                 marker_27abd6035cdbbcb9eb50592ee8ceae84.setIcon(icon_98086c641db4d1a1c6bed49379052c65);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:no

# %%
# 실습1

# 지도 생성
my_map2 = folium.Map(location=[37.61031195500979, 126.91293128637055], zoom_start=18)

# 기본 마커
folium.Marker(
    [37.61031195500979, 126.91293128637055],
    popup="Lecture Hall",
    tooltip="포스코 KDT 강의장",
    icon=folium.Icon(color="red", icon="fa-solid fa-chalkboard-user", prefix="fa-solid")
).add_to(my_map2)

# 강의장 반경 100m 표시
folium.Circle(
    location=[37.61031195500979, 126.91293128637055],
    radius=500,  # ← 미터 단위!
    color="#4a90e2",
    fill=True,
    fill_color="#4a90e2",
    fill_opacity=0.15,
    popup="반경 500m",
    tooltip="반경 500m 구역"
).add_to(my_map2)

# 토스트집
folium.Marker([37.60969565353592, 126.91412685010094], popup = "Toast", tooltip = "이삭토스트",
              icon = folium.Icon(color = "blue", icon = "fa-solid fa-bread-slice", prefix = "fa-solid")).add_to(my_map2)

# 지하철
folium.Marker([37.61124083903148, 126.91726514652655], popup = "Subway", tooltip = "구산역", 
              icon = folium.Icon(color = "orange", icon = "fa-solid fa-train-subway", prefix = "fa-solid")).add_to(my_map2)

# 공원
folium.Marker([37.61075165316152, 126.90761901698481], popup = "Park", tooltip = "근린공원", 
              icon = folium.Icon(color = "green", icon = "fa-solid fa-tree", prefix = "fa-solid")).add_to(my_map2)

my_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb6d94c38472151c2b15b289b187e73d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb6d94c38472151c2b15b289b187e73d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb6d94c38472151c2b15b289b187e73d = L.map(
#                 &quot;map_fb6d94c38472151c2b15b289b187e73d&quot;,
#                 {
#                     center: [37.61031195500979, 126.91293128637055],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 18,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eab9c37fbc6aac55ce4037884e0ace0c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eab9c37fbc6aac55ce4037884e0ace0c.addTo(map_fb6d94c38472151c2b15b289b187e73d);
#
#
#             var marker_596121429ce0c64a7eadae2f80d88ac9 = L.marker(
#                 [37.61031195500979, 126.91293128637055],
#                 {
# }
#             ).addTo(map_fb6d94c38472151c2b15b289b187e73d);
#
#
#             var icon_2aabc00e69893450d516c07e5e32fe06 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-solid fa-chalkboard-user&quot;,
#   &quot;prefix&quot;: &quot;fa-solid&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f1409461fc2c4183887b8ddbcbe477fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e89af8ddd7cd8977bd82a3b77a5b4a6 = $(`&lt;div id=&quot;html_7e89af8ddd7cd8977bd82a3b77a5b4a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lecture Hall&lt;/div&gt;`)[0];
#                 popup_f1409461fc2c4183887b8ddbcbe477fa.setContent(html_7e89af8ddd7cd8977bd82a3b77a5b4a6);
#
#
#
#         marker_596121429ce0c64a7eadae2f80d88ac9.bindPopup(popup_f1409461fc2c4183887b8ddbcbe477fa)
#         ;
#
#
#
#
#             marker_596121429ce0c64a7eadae2f80d88ac9.bindTooltip(
#                 `&lt;div&gt;
#                      포스코 KDT 강의장
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_596121429ce0c64a7eadae2f80d88ac9.setIcon(icon_2aabc00e69893450d516c07e5e32fe06);
#
#
#             var circle_d935bc696efee8e9844b6be9679a110e = L.circle(
#                 [37.61031195500979, 126.91293128637055],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4a90e2&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4a90e2&quot;, &quot;fillOpacity&quot;: 0.15, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 500, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fb6d94c38472151c2b15b289b187e73d);
#
#
#         var popup_42383b83a3f77d20cfc0ba6440889b7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48392b47f5f1e589e1cb48d81375d00f = $(`&lt;div id=&quot;html_48392b47f5f1e589e1cb48d81375d00f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;반경 500m&lt;/div&gt;`)[0];
#                 popup_42383b83a3f77d20cfc0ba6440889b7e.setContent(html_48392b47f5f1e589e1cb48d81375d00f);
#
#
#
#         circle_d935bc696efee8e9844b6be9679a110e.bindPopup(popup_42383b83a3f77d20cfc0ba6440889b7e)
#         ;
#
#
#
#
#             circle_d935bc696efee8e9844b6be9679a110e.bindTooltip(
#                 `&lt;div&gt;
#                      반경 500m 구역
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_5d1a7c7f5e4fd8e844ee3d59cb0fe233 = L.marker(
#                 [37.60969565353592, 126.91412685010094],
#                 {
# }
#             ).addTo(map_fb6d94c38472151c2b15b289b187e73d);
#
#
#             var icon_6fb96075772b2e16cf3daec2257636f7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-solid fa-bread-slice&quot;,
#   &quot;prefix&quot;: &quot;fa-solid&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d355cc2fbbf194ec56c9c76fcce39d64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b175aa994f1d3015fd0fa92b64d3b637 = $(`&lt;div id=&quot;html_b175aa9

# %%
# 실습2

df= pd.read_csv("./dataset/택시승차대 현황.csv", encoding = "cp949")
df.head(5)

taxi = df.loc[:, ["위치명", "위도", "경도"]]
taxi

lati = taxi["위도"].mean()
long = taxi["경도"].mean()

# %%
# 기본 지도 생성
my_map3 = folium.Map([lati, long] , zoom_start = 13)
for  idx, row in taxi.iterrows():
    # print(idx, row["위치명"], row["위도"], row["경도"])
    folium.Marker([row["위도"], row["경도"]], popup = "Taxi", tooltip = row["위치명"],
              icon = folium.Icon(color = "skyblue", icon = "fa-solid fa-taxi", prefix = "fa-solid")).add_to(my_map3)

my_map3
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_11740\2434574782.py:6: UserWarning: color argument of Icon should be one of: {'darkpurple', 'gray', 'lightblue', 'pink', 'lightgreen', 'darkred', 'black', 'green', 'blue', 'beige', 'orange', 'white', 'red', 'lightred', 'lightgray', 'purple', 'darkblue', 'cadetblue', 'darkgreen'}.
#   icon = folium.Icon(color = "skyblue", icon = "fa-solid fa-taxi", prefix = "fa-solid")).add_to(my_map3)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf83669b0057654167a916df51eb70ae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf83669b0057654167a916df51eb70ae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf83669b0057654167a916df51eb70ae = L.map(
#                 &quot;map_cf83669b0057654167a916df51eb70ae&quot;,
#                 {
#                     center: [37.55052018231854, 126.93522259155674],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bf76bbd9f86aedc6d5c7c636f25feab8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bf76bbd9f86aedc6d5c7c636f25feab8.addTo(map_cf83669b0057654167a916df51eb70ae);
#
#
#             var marker_0c8fbe276d5724ce7a88f89278c6fe45 = L.marker(
#                 [37.5453970345156, 126.952564116178],
#                 {
# }
#             ).addTo(map_cf83669b0057654167a916df51eb70ae);
#
#
#             var icon_39611d21291bcc53e5c739ffbee45543 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;skyblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-solid fa-taxi&quot;,
#   &quot;prefix&quot;: &quot;fa-solid&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0a4515dc14d4ff9a3b6ae063d52804ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_668bbc412c6b66b034dbcf30f07e2bce = $(`&lt;div id=&quot;html_668bbc412c6b66b034dbcf30f07e2bce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Taxi&lt;/div&gt;`)[0];
#                 popup_0a4515dc14d4ff9a3b6ae063d52804ac.setContent(html_668bbc412c6b66b034dbcf30f07e2bce);
#
#
#
#         marker_0c8fbe276d5724ce7a88f89278c6fe45.bindPopup(popup_0a4515dc14d4ff9a3b6ae063d52804ac)
#         ;
#
#
#
#
#             marker_0c8fbe276d5724ce7a88f89278c6fe45.bindTooltip(
#                 `&lt;div&gt;
#                      신용보증기금 마포지점 앞
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_0c8fbe276d5724ce7a88f89278c6fe45.setIcon(icon_39611d21291bcc53e5c739ffbee45543);
#
#
#             var marker_385652c1f4a67480ae1099244cb3ec33 = L.marker(
#                 [37.5520005467366, 126.95651212572],
#                 {
# }
#             ).addTo(map_cf83669b0057654167a916df51eb70ae);
#
#
#             var icon_2abbe7da4c3bcaac99d7c3e20dbe3911 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;skyblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-solid fa-taxi&quot;,
#   &quot;prefix&quot;: &quot;fa-solid&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e1ec410a9d6b34574e3d198abb89f708 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4cc827bdc1f6a873cc24411c7cfe8b04 = $(`&lt;div id=&quot;html_4cc827bdc1f6a873cc24411c7cfe8b04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Taxi&lt;/div&gt;`)[0];
#                 popup_e1ec410a9d6b34574e3d198abb89f708.setContent(html_4cc827bdc1f6a873cc24411c7cfe8b04);
#
#
#
#         marker_385652c1f4a67480ae1099244cb3ec33.bindPopup(popup_e1ec410a9d6b34574e3d198abb89f708)
#         ;
#
#
#
#
#             marker_385652c1f4a67480ae1099244cb3ec33.bindTooltip(
#                 `&lt;div&gt;
#                      마포SK허브 빌딩 앞
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_385652c1f4a67480ae1099244cb3ec33.setIcon(icon_2abbe7da4c3bcaac99d7c3e20dbe3911);
#
#
#             var marker_6ba9ec1f925f636b45ee7c9b2e793e92 = L.marker(
#                 [37.541448169111, 126.947232985498],
#                 {
# }
#             ).addTo(map_cf83669b0057654167a916df51eb70ae);
#
#
#             var icon_6df1e023b2b1b3ecd97fb28cca055020 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;skyblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-solid fa-taxi&quot;,
#   &quot;prefix&quot;: &quot;fa-solid&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_66fc50f392a5a0ed69bcec8695c291bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a3be0603f8a05469f50218177b85549 = $(`&lt;div id=&quot;html_9a3be0
