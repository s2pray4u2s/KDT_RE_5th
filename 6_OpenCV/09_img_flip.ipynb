# %%
import cv2

# %%
image = cv2.imread('images/Sparxie.webp')

# 좌우 반전
image_flip = cv2.flip(image, 1) # 1은 좌우 반전, 0은 상하 반전, -1은 둘 다 반전
cv2.imshow('Flipped Image', image_flip)

cv2.waitKey(0)
cv2.destroyAllWindows()
